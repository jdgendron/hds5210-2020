# %% [markdown]
# # Week 7 Assignment
#
# This week has been all about getting information off the internet both in structured data formats (CSV, JSON, etc) as well as HTML.  Answer the questions below as instructed.

# %% [markdown]
# ### 31.1 Finding files on the internet
#
# Go to healthdata.gov and find a file that looks interesting to you.  Provide the metadata below that describes the file you located.
#
# The cell below is a "markdown" cell.  Just double-click it to edit the contents and then Shift-Enter to show the content as formatted text.
#
# ---

# %% [markdown]
# **File Name:**  Lead_Testing_in_School_Drinking_Water_Sampling_and_Results_Compliance_Year_2016.csv
#
# **URL to Page:** https://healthdata.gov/dataset/lead-testing-school-drinking-water-sampling-and-results-compliance-year-2016
#
# **Description:** Lead Testing in School Drinking Water Sampling and Results Compliance Year 2016 for New York State
#
# **URL to Actual File:** https://health.data.ny.gov/api/views/rkyy-fsv9/rows.csv?accessType=DOWNLOAD
#
# **File Format:** CSV

# %% [markdown]
# ---

# %% [markdown]
# ### 31.2 Use Pandas to load data from internet
#
# Now write a block of code (doesn't need to be in a function) that will load the file using Pandas and describe the shape of the file contents.  I've provided a cell with some comments in it to help get you started.
#
# Pandas documentation for loading data https://pandas.pydata.org/pandas-docs/version/0.23.4/api.html#input-output
#
# Pandas documentation for describing the shape of data https://pandas.pydata.org/pandas-docs/version/0.23.4/generated/pandas.DataFrame.shape.html

# %%
import pandas as pd

# Load data using one of the read functions depending on your data file type
# data = pd.read_ ...
df = pd.read_csv('https://health.data.ny.gov/api/views/rkyy-fsv9/rows.csv?accessType=DOWNLOAD')
# Print out the row / column count
df.shape
# data. ...
df.head()
# Out:
#                       School District  \
# 0              BOCES No District Name
# 1              BOCES No District Name
# 2  EAST SYRACUSE-MINOA CENTRAL SCHOOL
# 3         NEW HARTFORD CENTRAL SCHOOL
# 4                 OSWEGO CITY SCHOOLS
#
#                                      School    County Type of Organization  \
# 0  GREATER SOUTHERN TIER BOCES STEM ACADEMY  Schuyler         BOCES School
# 1                            SULLIVAN BOCES  Sullivan         BOCES School
# 2                         MINOA ELEM SCHOOL  Onondaga        Public School
# 3                               PERRY J H S    Oneida        Public School
# 4                KINGSFORD PARK ELEM SCHOOL    Oswego        Public School
#
#    Number of Outlets Any Buildings with Lead-Free Plumbing?  \
# 0                NaN                                     No
# 1                NaN                                     No
# 2               93.0                                     No
# 3               84.0                                     No
# 4               59.0                                     No
#
#    Previously Sampled Outlets  Outlets Waiver Requested  Waivers Granted  \
# 0                         NaN                       NaN              NaN
# 1                         NaN                       NaN              NaN
# 2                        34.0                       0.0              0.0
# 3                         0.0                       0.0              0.0
# 4                        16.0                       0.0              0.0
#
#    Outlets Sampled After Regulation  ...            School Website\t  \
# 0                               NaN  ...                         NaN
# 1                               NaN  ...                         NaN
# 2                              59.0  ...              esmschools.org
# 3                              84.0  ...  www.newhartfordschools.org
# 4                              43.0  ...               ww.oswego.org
#
#       BEDS Code        School Street    School City School State  \
# 0  559008065001        3634 GOFF ROAD       CORNING           NY
# 1  599000000000           6 WIERK AVE       LIBERTY           NY
# 2  420401060009           501 MAIN ST         MINOA           NY
# 3  411501060006        9499 WESTON RD  NEW HARTFORD           NY
# 4  461300010005  W FIFTH & NIAGARA ST        OSWEGO           NY
#
#   School Zip Code Date Sampling Updated Date Results Updated  \
# 0           14830                   NaN                  NaN
# 1           12754                   NaN                  NaN
# 2           13116            03/27/2018           03/27/2018
# 3           13413            10/23/2018           10/23/2018
# 4           13126            11/11/2016           11/11/2016
#
#            County Location                                           Location
# 0   (42.38593, -76.872032)                  3634 GOFF ROAD\nCORNING, NY 14830
# 1  (41.705166, -74.711705)  6 WIERK AVE\nLIBERTY, NY 12754\n(41.795377, -7...
# 2  (43.065629, -76.168033)  501 MAIN ST\nMINOA, NY 13116\n(43.080676, -76....
# 3  (43.149482, -75.361773)  9499 WESTON RD\nNEW HARTFORD, NY 13413\n(43.05...
# 4    (43.39123, -76.31133)         W FIFTH &amp; NIAGARA ST\nOSWEGO, NY 13126
#
# [5 rows x 27 columns]

# %% [markdown]
# ---

# %% [markdown]
# ### 32.1 HTML Basics
#
# HTML is a form of which othere data format we've talked about:
#
# > A) Binary
# >
# > B) eXtensible Markup Language
# >
# > C) JavaScript Object Notation
# >
# > D) HL7 FHIR

# %%
answer321 = "B"

# %% [markdown]
# ### 32.2 Things in HTML
#
# Which of the following is **not** a part of HTML:
#
# > A) element
# >
# > B) tag
# >
# > C) dictionary
# >
# > D) attribute

# %%
answer322 = "C"

# %% [markdown]
# ### 32.3 Parsing HTML in Python
#
# Which of the following packages can be used to extract a table of data from HTML using Python (include all that apply in a list):
#
# > A) lxml
# >
# > B) BeautifulSoup
# >
# > C) Pandas
# >
# > D) fuzzywuzzy

# %%
answer323 = ["B","C"]
