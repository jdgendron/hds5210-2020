# %% [markdown]
# # Week 11 Exercises
#
# _McKinney 7.2, 11.1_
#
# The general activity that we are doing in this week's exercise is to explore and try to understand a particular data set.  In this case, it is
#
# 1. Read in the data file and filter down to only looking at MO hospitals
# 2. Aggregate by Hospital: sum the Denominator, use min Start Date, use max End Date  (watch for rows with no Denominator value!)
# 3. Calculate the average per day across that entire span
# 4. Histogram
# 5. Rank and find the hospital with the most

# %% [markdown]
# ## STEP 1 - Read and Filter
#
# <img src="images/step1.png" alt="Read and Filter Output" style="width: 500px; float: right; margin-left: 20px; border: 1px solid">
#
# In the first step, read in the data file from the data directory `/data/complications_all.csv`.  It is a CSV file and Pandas should read it in just fine.  Explore the file so that you understand the columns and values.  At the end of this step, create a variable called `mo_hospitals` that contains a data frame from the `complications_all.csv` file, filtered down to only contain those hospitals from the state of Missouri (MO).
#
# A screenshot is included for reference.

# %%
import pandas as pd
# This is just to show you the name to use for the variable you need to create for this step to pass.
mo_hospitals = pd.DataFrame()

# Put your code below and make sure that you reassign `mo_hospitals` 
# to have the contents described in the instructions.
all_hospitals = pd.read_csv('/data/complications_all.csv')
mo_hospitals = all_hospitals[(all_hospitals['State'] == 'MO')]

# %%
mo_hospitals
# Out:
#       Facility ID                    Facility Name           Address  \
# 45534      260001            MERCY HOSPITAL JOPLIN     100 MERCY WAY
# 45535      260001            MERCY HOSPITAL JOPLIN     100 MERCY WAY
# 45536      260001            MERCY HOSPITAL JOPLIN     100 MERCY WAY
# 45537      260001            MERCY HOSPITAL JOPLIN     100 MERCY WAY
# 45538      260001            MERCY HOSPITAL JOPLIN     100 MERCY WAY
# ...           ...                              ...               ...
# 47662      263304  SHRINERS HOSPITALS FOR CHILDREN  4400 CLAYTON AVE
# 47663      263304  SHRINERS HOSPITALS FOR CHILDREN  4400 CLAYTON AVE
# 47664      263304  SHRINERS HOSPITALS FOR CHILDREN  4400 CLAYTON AVE
# 47665      263304  SHRINERS HOSPITALS FOR CHILDREN  4400 CLAYTON AVE
# 47666      263304  SHRINERS HOSPITALS FOR CHILDREN  4400 CLAYTON AVE
#
#               City State  ZIP Code     County Name    Phone Number  \
# 45534       JOPLIN    MO     64804          JASPER  (417) 781-2727
# 45535       JOPLIN    MO     64804          JASPER  (417) 781-2727
# 45536       JOPLIN    MO     64804          JASPER  (417) 781-2727
# 45537       JOPLIN    MO     64804          JASPER  (417) 781-2727
# 45538       JOPLIN    MO     64804          JASPER  (417) 781-2727
# ...            ...   ...       ...             ...             ...
# 47662  SAINT LOUIS    MO     63110  ST. LOUIS CITY  (314) 432-3600
# 47663  SAINT LOUIS    MO     63110  ST. LOUIS CITY  (314) 432-3600
# 47664  SAINT LOUIS    MO     63110  ST. LOUIS CITY  (314) 432-3600
# 47665  SAINT LOUIS    MO     63110  ST. LOUIS CITY  (314) 432-3600
# 47666  SAINT LOUIS    MO     63110  ST. LOUIS CITY  (314) 432-3600
#
#             Measure ID                                       Measure Name  \
# 45534    COMP_HIP_KNEE  Rate of complications for hip/knee replacement...
# 45535      MORT_30_AMI               Death rate for heart attack patients
# 45536     MORT_30_CABG               Death rate for CABG surgery patients
# 45537     MORT_30_COPD                       Death rate for COPD patients
# 45538       MORT_30_HF              Death rate for heart failure patients
# ...                ...                                                ...
# 47662  PSI_4_SURG_COMP  Deaths among Patients with Serious Treatable C...
# 47663    PSI_6_IAT_PTX            Collapsed lung due to medical treatment
# 47664   PSI_8_POST_HIP               Broken hip from a fall after surgery
# 47665    PSI_90_SAFETY                              Serious complications
# 47666   PSI_9_POST_HEM          Perioperative Hemorrhage or Hematoma Rate
#
#                       Compared to National    Denominator          Score  \
# 45534  No Different Than the National Rate             26            2.5
# 45535  No Different Than the National Rate            175           13.9
# 45536  No Different Than the National Rate             91            2.5
# 45537  No Different Than the National Rate            326            8.5
# 45538  No Different Than the National Rate            461           13.1
# ...                                    ...            ...            ...
# 47662                        Not Available  Not Available  Not Available
# 47663                        Not Available  Not Available  Not Available
# 47664                        Not Available  Not Available  Not Available
# 47665                        Not Available  Not Available  Not Available
# 47666                        Not Available  Not Available  Not Available
#
#       Lower Estimate Higher Estimate  Footnote  Start Date    End Date
# 45534            1.4             4.2       NaN  04/01/2015  03/31/2018
# 45535           11.0            16.9       NaN  07/01/2015  06/30/2018
# 45536            1.2             5.1       NaN  07/01/2015  06/30/2018
# 45537            6.5            10.9       NaN  07/01/2015  06/30/2018
# 45538           10.7            15.9       NaN  07/01/2015  06/30/2018
# ...              ...             ...       ...         ...         ...
# 47662  Not Available   Not Available      19.0  07/01/2016  06/30/2018
# 47663  Not Available   Not Available      19.0  07/01/2016  06/30/2018
# 47664  Not Available   Not Available      19.0  07/01/2016  06/30/2018
# 47665  Not Available   Not Available      19.0  07/01/2016  06/30/2018
# 47666  Not Available   Not Available      19.0  07/01/2016  06/30/2018
#
# [2133 rows x 18 columns]

# %%
# These assertions will help make sure that you're on the right track.
assert(mo_hospitals['State'].unique() == ['MO'])
assert(mo_hospitals.shape == (2133,18))

# %% [markdown]
# ## STEP 2 - Transform and Aggregate
#
# <img src="images/step2.png" alt="Transforma and Aggregate Output" style="width: 500px; float: right; margin-left: 20px; border: 1px solid">
#
# In the next step, we need to aggregate the results by hospital.  There are some key fields that we want to summarize, though:
# * We want to know the earliest date that each hospital was participating in any program
# * We want to know the latest date that each hospital stopped participating in any program
# * We want to know the total number of patients in the denominators of these programs
#
# Some things to note:
# * You will need to convert the `Start Date` and `End Date` to actual datetime fields
# * You will need to clean up and convert the `Denominator` field to just be numeric - the rule that you should use it to simply remove any records where the `Denominator` is `'Not Available'`
#
# The final result of this step should be a new data frame called `mo_summary` that contains one row for each hospital and contains the min start date, max end date, and total denominator.  Use the names `start_date`, `end_date`, and `number` for those columns in `mo_summary`.
#
# A screenshot is included for reference.

# %%
# This is just to show you the name to use for the variable you need to create for this step to pass.


# Put your code below and make sure that you reassign `mo_summary` 
# to have the contents described in the instructions.
mo_hospitals = mo_hospitals[mo_hospitals['Denominator'] != 'Not Available']
start_date = pd.to_datetime(mo_hospitals['Start Date'].astype(str),format='%m/%d/%Y')
end_date = pd.to_datetime(mo_hospitals['End Date'].astype(str),format='%m/%d/%Y')
mo_hospitals['start'] = start_date
mo_hospitals['end'] = end_date
mo_hospitals['number'] = mo_hospitals['Denominator'].astype(int)
data_by_hospital = mo_hospitals.groupby('Facility Name')
mo_summary = data_by_hospital.aggregate({
    'start': ['min'], 
    'end': ['max'], 
    'number': ['sum']}).reset_index()
mo_summary.columns = ['Facility Name','start_date','end_date','number']
mo_summary
# Out:
#                                          Facility Name start_date   end_date  \
# 0                               BARNES JEWISH HOSPITAL 2015-04-01 2018-06-30
# 1                     BARNES-JEWISH ST PETERS HOSPITAL 2015-04-01 2018-06-30
# 2                   BARNES-JEWISH WEST COUNTY HOSPITAL 2015-04-01 2018-06-30
# 3                       BATES COUNTY MEMORIAL HOSPITAL 2015-07-01 2018-06-30
# 4                       BELTON REGIONAL MEDICAL CENTER 2015-04-01 2018-06-30
# 5                                BOONE HOSPITAL CENTER 2015-04-01 2018-06-30
# 6                      BOTHWELL REGIONAL HEALTH CENTER 2015-04-01 2018-06-30
# 7                      CAMERON REGIONAL MEDICAL CENTER 2015-04-01 2018-06-30
# 8                        CAPITAL REGION MEDICAL CENTER 2015-04-01 2018-06-30
# 9                     CARROLL COUNTY MEMORIAL HOSPITAL 2015-07-01 2018-06-30
# 10                        CASS REGIONAL MEDICAL CENTER 2015-04-01 2018-06-30
# 11                      CEDAR COUNTY MEMORIAL HOSPITAL 2015-07-01 2018-06-30
# 12                          CENTERPOINT MEDICAL CENTER 2015-04-01 2018-06-30
# 13              CHRISTIAN HOSPITAL NORTHEAST-NORTHWEST 2015-04-01 2018-06-30
# 14                          CITIZENS MEMORIAL HOSPITAL 2015-04-01 2018-06-30
# 15                       COLUMBIA MO VA MEDICAL CENTER 2015-07-01 2018-06-30
# 16                      COMMUNITY HOSPITAL ASSOCIATION 2015-07-01 2018-06-30
# 17                    COOPER COUNTY COMMUNITY HOSPITAL 2015-07-01 2018-06-30
# 18                          COX BARTON COUNTY HOSPITAL 2015-04-01 2018-06-30
# 19                          COX MEDICAL CENTER BRANSON 2015-04-01 2018-06-30
# 20                                 COX MEDICAL CENTERS 2015-04-01 2018-06-30
# 21                                 COX MONETT HOSPITAL 2015-07-01 2018-06-30
# 22                            ELLETT MEMORIAL HOSPITAL 2015-07-01 2018-06-30
# 23                          EXCELSIOR SPRINGS HOSPITAL 2015-07-01 2018-06-30
# 24                                 FITZGIBBON HOSPITAL 2015-04-01 2018-06-30
# 25                FREEMAN HEALTH SYSTEM - FREEMAN WEST 2015-04-01 2018-06-30
# 26                             FREEMAN NEOSHO HOSPITAL 2015-07-01 2018-06-30
# 27                           FULTON MEDICAL CENTER LLC 2016-07-01 2018-06-30
# 28                     GOLDEN VALLEY MEMORIAL HOSPITAL 2015-04-01 2018-06-30
UNTY MEMORIAL HOSPITAL 2015-07-01 2018-06-30
# 106                    WESTERN MISSOURI MEDICAL CENTER 2015-04-01 2018-06-30
# 107                           WRIGHT MEMORIAL HOSPITAL 2015-07-01 2018-06-30
#
#      number
# 0    131313
# 1     15668
# 2      9622
# 3      3117
# 4      9270
# 5     63099
# 6     14717
# 7      6066
# 8     17598
# 9        81
# 10      289
# 11       53
# 12    35106
# 13    31846
# 14     7529
# 15      890
# 16      184
# 17      697
# 18      201
# 19    16633
# 20    69169
# 21       98
# 22       97
# 23       47
# 24     3669
# 25    53519
# 26      258
# 27      184
# 28     6360
# 29    17532
# 30      167
# 31      359
# 32      119
# 33       26
# 34       99
# 35      942
# 36      194
# 37    16028
# 38    11806
# 39    24716
# 40      264
# 41      103
# 42       96
# 43      153
# 44       98
# 45    23770
# 46    29977
# 47     5665
# 48      161
# 49    62487
# 50    81264
# 51    68665
# 52    14175
# 53       60
# 54    62915
# 55      275
# 56    11091
# 57     3860
# 58    54860
# 59     2477
# 60      117
# 61     2001
# 62    61446
# 63     7736
# 64    13697
# 65     9731
# 66     3891
# 67      488
# 68      179
# 69    16014
# 70      211
# 71    25166
# 72      226
# 73     5931
# 74       71
# 75      204
# 76    32514
# 77    45199
# 78    35865
# 79    15695
# 80      339
# 81      117
# 82    33762
# 83     2810
# 84    51585
# 85    24239
# 86    29630
# 87    28080
# 88    23443
# 89    26998
# 90    20531
# 91     5543
# 92     5712
# 93    22538
# 94     1062
# 95    13142
# 96    52987
# 97    58487
# 98    13610
# 99      291
# 100      40
# 101    3609
# 102   11725
# 103    4297
# 104   56493
# 105     220
# 106    7254
# 107     198

# %%
assert(mo_summary['number'].sum() == 1766908)
assert(mo_summary['start_date'].min() == pd.Timestamp(2015,4,1))
assert(mo_summary['end_date'].max() == pd.Timestamp(2018,6,30))
assert(mo_summary.shape == (108,4))
assert(mo_summary.loc['BARNES JEWISH HOSPITAL'].number == 131313)
assert(mo_summary.loc['BOONE HOSPITAL CENTER'].number == 63099)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/tljh/user/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'BARNES JEWISH HOSPITAL'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-0d95bb8cb68d> in <module>
#       3 assert(mo_summary['end_date'].max() == pd.Timestamp(2018,6,30))
#       4 assert(mo_summary.shape == (108,4))
# ----> 5 assert(mo_summary.loc['BARNES JEWISH HOSPITAL'].number == 131313)
#       6 assert(mo_summary.loc['BOONE HOSPITAL CENTER'].number == 63099)
#
# /opt/tljh/user/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1765
#    1766             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1767             return self._getitem_axis(maybe_callable, axis=axis)
#    1768
#    1769     def _is_scalar_access(self, key: Tuple):
#
# /opt/tljh/user/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1962         # fall thru to straight lookup
#    1963         self._validate_key(key, axis)
# -> 1964         return self._get_label(key, axis=axis)
#    1965
#    1966
#
# /opt/tljh/user/lib/python3.6/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#     622             raise IndexingError("no slices here, handle elsewhere")
#     623
# --> 624         return self.obj._xs(label, axis=axis)
#     625
#     626     def _get_loc(self, key: int, axis: int):
#
# /opt/tljh/user/lib/python3.6/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3535             loc, new_index = self.index.get_loc_level(key, drop_level=drop_level)
#    3536         else:
# -> 3537             loc = self.index.get_loc(key)
#    3538
#    3539             if isinstance(loc, np.ndarray):
#
# /opt/tljh/user/lib/python3.6/site-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     351             except ValueError:
#     352                 raise KeyError(key)
# --> 353         return super().get_loc(key, method=method, tolerance=tolerance)
#     354
#     355     @Appender(_index_shared_docs["get_indexer"])
#
# /opt/tljh/user/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'BARNES JEWISH HOSPITAL'

# %% [markdown]
# ## STEP 3: Average Per Day
#
# <img src="images/step3.png" alt="Average per Day" style="width: 500px; margin-left: 20px; float: right; border: 1px solid">
#
#
# The next step, now that we have a start date, end date, and total patients for each day is to calculate how many patients on average per day this represents.  You will need to calculate the number of days between the start date and end date, and then the average as total patients divided by number of days.
#
# Your final output should still be the variable `mo_summary`, and it will need to have two additional columns: `days` and `per_day`.
#
# A screenshot is included for reference.

# %%
# Put your code below and make sure that you add new columns to `mo_summary` 
# to have the contents described in the instructions.
mo_hospitals['days'] = (mo_hospitals.end - mo_hospitals.start).dt.days
mo_summary['days'] = (mo_summary['end_date'] - mo_summary['start_date']).dt.days
mo_summary['per_day'] = mo_summary['number'] / mo_summary['days']
mo_summary.head()
# Out:
#                         Facility Name start_date   end_date  number  days  \
# 0              BARNES JEWISH HOSPITAL 2015-04-01 2018-06-30  131313  1186
# 1    BARNES-JEWISH ST PETERS HOSPITAL 2015-04-01 2018-06-30   15668  1186
# 2  BARNES-JEWISH WEST COUNTY HOSPITAL 2015-04-01 2018-06-30    9622  1186
# 3      BATES COUNTY MEMORIAL HOSPITAL 2015-07-01 2018-06-30    3117  1095
# 4      BELTON REGIONAL MEDICAL CENTER 2015-04-01 2018-06-30    9270  1186
#
#       per_day
# 0  110.719224
# 1   13.210793
# 2    8.112985
# 3    2.846575
# 4    7.816189

# %%
assert(mo_summary['days'].sum() == 123718)
assert(mo_summary['per_day'].mean() == 13.841279932122697)
assert(mo_summary['per_day'].min() == 0.023744292237442923)
assert(mo_summary['days'].min() == 729)
assert(mo_summary['days'].max() == 1186)

# %% [markdown]
# ## STEP 4: Histogram
#
# <img src="images/step4.png" alt="Histogram" style="width: 300px; float: right; margin-left: 20px; border: 1px solid">
#
# For this step, I want you to plot a histogram to give yourself a better understanding of this new metric we've calculated: how many patients per day have a potential complication.  Looking at the shape and distribution of the data might give us some indication of the hospital volume and quality.  (Don't take this too seriously, though.  We're cutting some important corners.)
#
# A screenshot is included for reference.

# %%
# %matplotlib inline
# Use the built-in Pandas histogram plotting capability to plot a histogram of the `per_day` values.
mo_summary['per_day'].hist()

# %% [markdown]
# ## STEP 5: Rank Order
#
# Now that we see what the distribution looks like, you can tell that most of the `per_day` values are below 20.  There are, however, some outliers up around 100!  Who are those?  Let's rank the data set by the `per_day` value in descending order, examine them, and produce a list of the "top 3" based on this criteria.  That is, who are the top three hospitals based on having the highest `per_day` values.
#
# At the end of this step, put those hospital names in a list called `top_hospitals` and that will be used for testing.  They should be in the order they appear `[#1, #2, #3]`.  That is, if the top hospitals were Mercy (99.3), BJC (97.2), and MoBap (90.1), then you would have `top_hospitals = ['Mercy','BJC','MoBap']`

# %%
# Put your code below and make sure that your final result ends up in the variable `top_hospitals`
# as described in the instructions above.
mo_summary['rank'] = mo_summary['per_day'].rank()
per_day_rank = mo_summary.sort_values('rank', ascending=False)
top_hospitals_data = per_day_rank['Facility Name'][0:3]

top_hospitals = []
for hos in top_hospitals_data:
    top_hospitals.append(hos)
top_hospitals
# Out:
# ['BARNES JEWISH HOSPITAL', 'MERCY HOSPITAL SPRINGFIELD', 'COX MEDICAL CENTERS']

# %%
assert(type(top_hospitals) == list)
### BEGIN HIDDEN TESTS
assert(top_hospitals == ['BARNES JEWISH HOSPITAL', 'MERCY HOSPITAL SPRINGFIELD', 'COX MEDICAL CENTERS'])
### END HIDDEN TESTS
